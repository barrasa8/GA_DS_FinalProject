# %% [markdown]
# # Web user volumes prediction using IIS logs

# %% [markdown]
# The intent of this analysis is to create a model that can predict the user volume connecting to the website. To achive this, we have 8 months worht of IIS logs for a particular client from December 2017 to start of Ocboter 2018.

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

# %%
log_file = 'C:/Users/ioltra/Documents/QuantumIT/GA_DS_FinalProject/data/u_ex171207.log'

# %%
#iis_log_df = pd.read_csv()
df = pd.read_csv(log_file
                ,skiprows=[0,1,2,3]
                ,sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])', 
                engine='python', 
                na_values='-', 
                header=None,
                usecols=[0, 3, 4, 5, 6, 7, 8],
                names=['ip', 'time', 'request', 'status', 'size', 'referer', 'user_agent'])

# %%
df.head()
# Out:
#            ip time                                request  \
# 0  2017-12-07  GET                                      /
# 1  2017-12-07  GET                            /Login.aspx
# 2  2017-12-07  GET  /Security/Account.mvc/LogOnFederation
# 3  2017-12-07  GET                       /Scripts/angular
# 4  2017-12-07  GET       /Content/Styles/global-bootstrap
#
#                                            status  size  referer  \
# 0                                             NaN   443      NaN
# 1                                   ReturnUrl=%2f   443      NaN
# 2                                   ReturnUrl=%2f   443      NaN
# 3  v=ZLF68Gqwmuuh2ZvHcQpEuU1xkWptxwOpRzXwwMGaiN01   443      NaN
# 4  v=84kf7GIBdMhYIINVmeCDSHFVxrD5iToJR-sVWXPTNo81   443      NaN
#
#         user_agent
# 0  144.139.133.243
# 1  144.139.133.243
# 2  144.139.133.243
# 3  144.139.133.243
# 4  144.139.133.243

# %%
#iis_log_df = pd.read_csv()
df2 = pd.read_csv(log_file
                ,skiprows=[0,1,2,3]
                ,sep=r'\s', 
                engine='python', 
                na_values='-', 
                header=None,
                usecols=[0, 1, 4, 5, 6, 7, 8],
                names=['ip', 'time', 'request', 'status', 'size', 'referer', 'user_agent'])

df2.head()
# Out:
#            ip      time                                request  \
# 0  2017-12-07  23:11:17                                      /
# 1  2017-12-07  23:11:20                            /Login.aspx
# 2  2017-12-07  23:11:40  /Security/Account.mvc/LogOnFederation
# 3  2017-12-07  23:11:40                       /Scripts/angular
# 4  2017-12-07  23:11:40       /Content/Styles/global-bootstrap
#
#                                            status  size  referer  \
# 0                                             NaN   443      NaN
# 1                                   ReturnUrl=%2f   443      NaN
# 2                                   ReturnUrl=%2f   443      NaN
# 3  v=ZLF68Gqwmuuh2ZvHcQpEuU1xkWptxwOpRzXwwMGaiN01   443      NaN
# 4  v=84kf7GIBdMhYIINVmeCDSHFVxrD5iToJR-sVWXPTNo81   443      NaN
#
#         user_agent
# 0  144.139.133.243
# 1  144.139.133.243
# 2  144.139.133.243
# 3  144.139.133.243
# 4  144.139.133.243
